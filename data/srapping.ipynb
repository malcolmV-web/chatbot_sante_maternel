# %% [markdown]
# ## Grossesse Prenatale Part1

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Liste des URLs à scraper
urls_articles = [
    "https://www.nestlebaby.be/fr/symptomes-grossesse",
    "https://www.nestlebaby.be/fr/check-list-valise-de-maternite",
    "https://www.nestlebaby.be/fr/semaines-de-grossesse-en-mois",
    "https://www.nestlebaby.be/fr/neuvieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/huitieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/septieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/sixieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/5-conseils-alimentation-grossesse",
    "https://www.nestlebaby.be/fr/fringales-grossesse",
    "https://www.nestlebaby.be/fr/maux-grossesse",
    "https://www.nestlebaby.be/fr/alimentation-grossesse-que-manger",
    "https://www.nestlebaby.be/fr/vitamines-grossesse",
    "https://www.nestlebaby.be/fr/grossesse-fer",
    "https://www.nestlebaby.be/fr/grossesse-acide-folique-fer",
    "https://www.nestlebaby.be/fr/diabete-gestationnel",
    "https://www.nestlebaby.be/fr/grossesse-acides-gras-essentiels",
    "https://www.nestlebaby.be/fr/calcium-vitamine-d-bebe",
    "https://www.nestlebaby.be/fr/prise-poids-grossesse",
    "https://www.nestlebaby.be/fr/tension-grossesse",
    "https://www.nestlebaby.be/fr/preparer-allaitement",
    "https://www.nestlebaby.be/fr/faire-sport-enceinte",
    "https://www.nestlebaby.be/fr/bienfaits-allaitement-bebe",
    "https://www.nestlebaby.be/fr/quand-faire-un-test-de-grossesse",
    "https://www.nestlebaby.be/fr/questions-grossesse",
    "https://www.nestlebaby.be/fr/preparer-arrivee-bebe",
    "https://www.nestlebaby.be/fr/demarches-administratives-enceinte",
    "https://www.nestlebaby.be/fr/signes-de-travail-accouchement",
    "https://www.nestlebaby.be/fr/questions-diagnostic-prenatal",
    "https://www.nestlebaby.be/fr/cesarienne-a-quoi-s-attendre",
    "https://www.nestlebaby.be/fr/insomnies-grossesse-causes-et-solutions",
    "https://www.nestlebaby.be/fr/causes-accouchement-premature",
    "https://www.nestlebaby.be/fr/communiquer-avec-bebe-pendant-grossesse",
    "https://www.nestlebaby.be/fr/examens-controles-grossesse",
    "https://www.nestlebaby.be/fr/angoisse-grossesse-premier-trimestre"
    "https://www.nestlebaby.be/fr/questions-premiere-echographie",
    "https://www.nestlebaby.be/fr/questions-premier-rendez-vous-prenatal",
    "https://www.nestlebaby.be/fr/31-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/enceinte-jumeaux",
    "https://www.nestlebaby.be/fr/cinquieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/rencontre-bebe",
    "https://www.nestlebaby.be/fr/10-conseils-dormir-grossesse",
    "https://www.nestlebaby.be/fr/3-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/4-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/5-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/6-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/7-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/8-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/9-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/10-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/11-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/12-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/13-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/14-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/15-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/16-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/18-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/19-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/20-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/21-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/22-semaine-de-grossesse"
    "https://www.nestlebaby.be/fr/23-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/24-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/25-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/26-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/27-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/28-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/29-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/30-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/32-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/34-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/35-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/36-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/37-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/38-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/39-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/40-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/33-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/retablissement-apres-cesarienne",
    "https://www.nestlebaby.be/fr/checklist-conge-maternite-paternite",
    "https://www.nestlebaby.be/fr/calmer-nausees-grossesse",
    "https://www.nestlebaby.be/fr/voyage-en-securite-bebe",
    "https://www.nestlebaby.be/fr/choisir-maternite",
    "https://www.nestlebaby.be/fr/douleurs-de-grossesse",
    "https://www.nestlebaby.be/fr/vetements-grossesse",
    "https://www.nestlebaby.be/fr/preparer-une-baby-shower",
    "https://www.nestlebaby.be/fr/etapes-accouchement",
    "https://www.nestlebaby.be/fr/faire-amour-enceinte",
    "https://www.nestlebaby.be/fr/grossesse-types-accouchement",
    "https://www.nestlebaby.be/fr/changements-corps-grossesse",
    "https://www.nestlebaby.be/fr/devenir-parents"
]

donnees = []
id_count = 1

for url_article in urls_articles:
    response = requests.get(url_article)
    if response.status_code != 200:
        print(f"Erreur de connexion à {url_article} : {response.status_code}")
        continue
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    # h1
    h1 = soup.find("h1")
    if h1:
        question = h1.get_text(strip=True)
        p_tags = h1.find_next_siblings("p")
        reponse = "\n".join([p.get_text(strip=True) for p in p_tags])
        if reponse:
            donnees.append({
                "id": id_count,
                "question": question,
                "reponse": reponse,
                "categorie": "grossesse prenatale"
            })
            id_count += 1
    
    # h2
    for h2 in soup.find_all("h2"):
        question = h2.get_text(strip=True)
        p_tags = h2.find_next_siblings("p")
        reponse = "\n".join([p.get_text(strip=True) for p in p_tags])
        if reponse:
            donnees.append({
                "id": id_count,
                "question": question,
                "reponse": reponse,
                "categorie": "grossesse prenatale"
            })
            id_count += 1
    
    time.sleep(1)  # pause pour respecter le serveur

# Sauvegarde CSV
with open("articles_grossesse_prenatales.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["id","question","reponse","categorie"])
    writer.writeheader()
    writer.writerows(donnees)

print(f"{len(donnees)} Q/R extraites et sauvegardées dans CSV.")
# Out:
# Erreur de connexion à https://www.nestlebaby.be/fr/angoisse-grossesse-premier-trimestrehttps://www.nestlebaby.be/fr/questions-premiere-echographie : 404
# Erreur de connexion à https://www.nestlebaby.be/fr/22-semaine-de-grossessehttps://www.nestlebaby.be/fr/23-semaine-de-grossesse : 404
# 176 Q/R extraites et sauvegardées dans CSV.

# %% [markdown]
# ## Grossesse Postnatales Part1

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Liste des URLs à scraper
urls = [
    "https://www.nestlebaby.be/fr/quel-lait-infantile-choisir",
    "https://www.nestlebaby.be/fr/quantite-biberon-bebe",
    "https://www.nestlebaby.be/fr/decrypter-couleur-selles-bebe",
    "https://www.nestlebaby.be/fr/soulager-coliques-bebe",
    "https://www.nestlebaby.be/fr/aliments-solides-bebe-nouvelles-etapes",
    "https://www.nestlebaby.be/fr/soulager-bebe-mal-de-dent",
    "https://www.nestlebaby.be/fr/apprentissage-biberon-allaitement",
    "https://www.nestlebaby.be/fr/premiere-puree-legumes-bebe",
    "https://www.nestlebaby.be/fr/alimentation-equilibree-jeunes-enfants",
    "https://www.nestlebaby.be/fr/kit-de-diversification-alimentaire-bebe",
    "https://www.nestlebaby.be/fr/preparation-biberon-bebe",
    "https://www.nestlebaby.be/fr/quel-biberon-choisir",
    "https://www.nestlebaby.be/fr/preparer-allaitement",
    "https://www.nestlebaby.be/fr/cereales-energie-bebe",
    "https://www.nestlebaby.be/fr/conseils-pour-donner-le-biberon",
    "https://www.nestlebaby.be/fr/comprendre-pleurs-bebe",
    "https://www.nestlebaby.be/fr/developpement-cerebral-bebe",
    "https://www.nestlebaby.be/fr/sevrage-arreter-allaitement",
    "https://www.nestlebaby.be/fr/laver-bebe",
    "https://www.nestlebaby.be/fr/etapes-developpement-bebe",
    "https://www.nestlebaby.be/fr/bienfaits-allaitement-bebe",
    "https://www.nestlebaby.be/fr/bien-dormir-bebe",
    "https://www.nestlebaby.be/fr/a-qui-confier-bebe",
    "https://www.nestlebaby.be/fr/bobo-ventre-bebe",
    "https://www.nestlebaby.be/fr/allaitement-travail",
    "https://www.nestlebaby.be/fr/manger-allaitement",
    "https://www.nestlebaby.be/fr/allaitement-mixte-alterner-biberon",
    "https://www.nestlebaby.be/fr/masser-bebe",
    "https://www.nestlebaby.be/fr/premiere-dent-bebe",
    "https://www.nestlebaby.be/fr/proteines-lait-maternel-allergies",
    "https://www.nestlebaby.be/fr/lait-maternel-nutrition",
    "https://www.nestlebaby.be/fr/prevenir-obesite-enfants",
    "https://www.nestlebaby.be/fr/diarrhee-bebe",
    "https://www.nestlebaby.be/fr/commencer-donner-nourriture-bebe",
    "https://www.nestlebaby.be/fr/conseils-habitudes-sommeil-de-bebe",
    "https://www.nestlebaby.be/fr/importance-proteines-lait-maternel",
    "https://www.nestlebaby.be/fr/sommeil-bebe-6-12-mois",
    "https://www.nestlebaby.be/fr/plan-d-action-contre-les-coliques",
    "https://www.nestlebaby.be/fr/positions-allaitement",
    "https://www.nestlebaby.be/fr/questions-visite-obligatoire-de-bebe",
    "https://www.nestlebaby.be/fr/troubles-du-sommeil-de-bebe",
    "https://www.nestlebaby.be/fr/cauchemars-bebe",
    "https://www.nestlebaby.be/fr/conseils-pour-allaitement",
    "https://www.nestlebaby.be/fr/vaccination-du-bebe",
    "https://www.nestlebaby.be/fr/constipation-bebe",
    "https://www.nestlebaby.be/fr/comment-donner-le-bain-a-bebe",
    "https://www.nestlebaby.be/fr/pourquoi-les-bebes-pleurent",
    "https://www.nestlebaby.be/fr/calcium-os-bebe",
    "https://www.nestlebaby.be/fr/allaitement-quantite-lait",
    "https://www.nestlebaby.be/fr/avantages-allaitement-maman",
    "https://www.nestlebaby.be/fr/bebe-pleure"
]


donnees = []
id_count = 1

for url_article in urls_articles:
    response = requests.get(url_article)
    if response.status_code != 200:
        print(f"Erreur de connexion à {url_article} : {response.status_code}")
        continue
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    # h1
    h1 = soup.find("h1")
    if h1:
        question = h1.get_text(strip=True)
        p_tags = h1.find_next_siblings("p")
        reponse = "\n".join([p.get_text(strip=True) for p in p_tags])
        if reponse:
            donnees.append({
                "id": id_count,
                "question": question,
                "reponse": reponse,
                "categorie": "grossesse postnatale"
            })
            id_count += 1
    
    # h2
    for h2 in soup.find_all("h2"):
        question = h2.get_text(strip=True)
        p_tags = h2.find_next_siblings("p")
        reponse = "\n".join([p.get_text(strip=True) for p in p_tags])
        if reponse:
            donnees.append({
                "id": id_count,
                "question": question,
                "reponse": reponse,
                "categorie": "grossesse postnatale"
            })
            id_count += 1
    
    time.sleep(1)  # pause pour respecter le serveur

# Sauvegarde CSV
with open("articles_grossesse_postnatale.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["id","question","reponse","categorie"])
    writer.writeheader()
    writer.writerows(donnees)

print(f"{len(donnees)} Q/R extraites et sauvegardées dans CSV.")
# Out:
# Erreur de connexion à https://www.nestlebaby.be/fr/angoisse-grossesse-premier-trimestrehttps://www.nestlebaby.be/fr/questions-premiere-echographie : 404
# Erreur de connexion à https://www.nestlebaby.be/fr/22-semaine-de-grossessehttps://www.nestlebaby.be/fr/23-semaine-de-grossesse : 404
# 176 Q/R extraites et sauvegardées dans CSV.

# %% [markdown]
# ## Grossesse Prenatales

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# === Liste d'URLs  ===
urls = [
    "https://www.nestlebaby.be/fr/symptomes-grossesse",
    "https://www.nestlebaby.be/fr/check-list-valise-de-maternite",
    "https://www.nestlebaby.be/fr/semaines-de-grossesse-en-mois",
    "https://www.nestlebaby.be/fr/neuvieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/huitieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/septieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/sixieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/5-conseils-alimentation-grossesse",
    "https://www.nestlebaby.be/fr/fringales-grossesse",
    "https://www.nestlebaby.be/fr/maux-grossesse",
    "https://www.nestlebaby.be/fr/alimentation-grossesse-que-manger",
    "https://www.nestlebaby.be/fr/vitamines-grossesse",
    "https://www.nestlebaby.be/fr/grossesse-fer",
    "https://www.nestlebaby.be/fr/grossesse-acide-folique-fer",
    "https://www.nestlebaby.be/fr/diabete-gestationnel",
    "https://www.nestlebaby.be/fr/grossesse-acides-gras-essentiels",
    "https://www.nestlebaby.be/fr/calcium-vitamine-d-bebe",
    "https://www.nestlebaby.be/fr/prise-poids-grossesse",
    "https://www.nestlebaby.be/fr/tension-grossesse",
    "https://www.nestlebaby.be/fr/preparer-allaitement",
    "https://www.nestlebaby.be/fr/faire-sport-enceinte",
    "https://www.nestlebaby.be/fr/bienfaits-allaitement-bebe",
    "https://www.nestlebaby.be/fr/quand-faire-un-test-de-grossesse",
    "https://www.nestlebaby.be/fr/questions-grossesse",
    "https://www.nestlebaby.be/fr/preparer-arrivee-bebe",
    "https://www.nestlebaby.be/fr/demarches-administratives-enceinte",
    "https://www.nestlebaby.be/fr/signes-de-travail-accouchement",
    "https://www.nestlebaby.be/fr/questions-diagnostic-prenatal",
    "https://www.nestlebaby.be/fr/cesarienne-a-quoi-s-attendre",
    "https://www.nestlebaby.be/fr/insomnies-grossesse-causes-et-solutions",
    "https://www.nestlebaby.be/fr/causes-accouchement-premature",
    "https://www.nestlebaby.be/fr/communiquer-avec-bebe-pendant-grossesse",
    "https://www.nestlebaby.be/fr/examens-controles-grossesse",
    "https://www.nestlebaby.be/fr/angoisse-grossesse-premier-trimestre",
    "https://www.nestlebaby.be/fr/questions-premiere-echographie",
    "https://www.nestlebaby.be/fr/questions-premier-rendez-vous-prenatal",
    "https://www.nestlebaby.be/fr/31-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/enceinte-jumeaux",
    "https://www.nestlebaby.be/fr/cinquieme-mois-grossesse",
    "https://www.nestlebaby.be/fr/rencontre-bebe",
    "https://www.nestlebaby.be/fr/10-conseils-dormir-grossesse",
    "https://www.nestlebaby.be/fr/3-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/4-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/5-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/6-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/7-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/8-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/9-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/10-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/11-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/12-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/13-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/14-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/15-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/16-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/18-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/19-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/20-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/21-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/22-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/23-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/24-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/25-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/26-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/27-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/28-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/29-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/30-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/32-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/33-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/34-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/35-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/36-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/37-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/38-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/39-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/40-semaine-de-grossesse",
    "https://www.nestlebaby.be/fr/retablissement-apres-cesarienne",
    "https://www.nestlebaby.be/fr/checklist-conge-maternite-paternite",
    "https://www.nestlebaby.be/fr/calmer-nausees-grossesse",
    "https://www.nestlebaby.be/fr/voyage-en-securite-bebe",
    "https://www.nestlebaby.be/fr/choisir-maternite",
    "https://www.nestlebaby.be/fr/douleurs-de-grossesse",
    "https://www.nestlebaby.be/fr/vetements-grossesse",
    "https://www.nestlebaby.be/fr/preparer-une-baby-shower",
    "https://www.nestlebaby.be/fr/etapes-accouchement",
    "https://www.nestlebaby.be/fr/faire-amour-enceinte",
    "https://www.nestlebaby.be/fr/grossesse-types-accouchement",
    "https://www.nestlebaby.be/fr/changements-corps-grossesse",
    "https://www.nestlebaby.be/fr/devenir-parents"
]

# === Fichier CSV de sortie ===
csv_filename = "grossesse_prenatales.csv"

# Création du fichier CSV
with open(csv_filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["id", "question", "reponse", "categorie"])

    id_counter = 1

    for url in urls:
        print(f"Scraping : {url}")
        try:
            response = requests.get(url, timeout=15)
            if response.status_code != 200:
                print(f" Erreur {response.status_code} pour {url}")
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extraction des titres h1 et h2 (considérés comme "questions")
            titles = [h.get_text(strip=True) for h in soup.find_all(["h1", "h2"])]

            # Extraction du texte des paragraphes
            paragraphs = [p.get_text(strip=True) for p in soup.find_all("p")]

            # On fusionne le contenu pour obtenir une "réponse" cohérente
            reponse = " ".join(paragraphs)

            # Catégorie = 'grossesse' (à modifier selon besoin)
            categorie = "grossesse prenatale"

            # Enregistrement dans le CSV
            for title in titles:
                writer.writerow([id_counter, title, reponse, categorie])
                id_counter += 1

            print(f" {url} traité ({len(titles)} questions)")

        except Exception as e:
            print(f" Erreur sur {url} : {e}")

        time.sleep(1)  # petite pause pour éviter surcharge du site

print(f"\n Extraction terminée ! Données enregistrées dans {csv_filename}")
# Out:
# Scraping : https://www.nestlebaby.be/fr/symptomes-grossesse
#  https://www.nestlebaby.be/fr/symptomes-grossesse traité (6 questions)
# Scraping : https://www.nestlebaby.be/fr/check-list-valise-de-maternite
#  https://www.nestlebaby.be/fr/check-list-valise-de-maternite traité (6 questions)
# Scraping : https://www.nestlebaby.be/fr/semaines-de-grossesse-en-mois
#  https://www.nestlebaby.be/fr/semaines-de-grossesse-en-mois traité (8 questions)
# Scraping : https://www.nestlebaby.be/fr/neuvieme-mois-grossesse
#  https://www.nestlebaby.be/fr/neuvieme-mois-grossesse traité (4 questions)
# Scraping : https://www.nestlebaby.be/fr/huitieme-mois-grossesse
#  https://www.nestlebaby.be/fr/huitieme-mois-grossesse traité (4 questions)
# Scraping : https://www.nestlebaby.be/fr/septieme-mois-grossesse
#  https://www.nestlebaby.be/fr/septieme-mois-grossesse traité (4 questions)
# Scraping : https://www.nestlebaby.be/fr/sixieme-mois-grossesse
# ...

# %% [markdown]
# ## Grossesse Postnatale

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# === Liste d'URLs  ===
urls = [
    "https://www.nestlebaby.be/fr/quel-lait-infantile-choisir",
    "https://www.nestlebaby.be/fr/quantite-biberon-bebe",
    "https://www.nestlebaby.be/fr/decrypter-couleur-selles-bebe",
    "https://www.nestlebaby.be/fr/soulager-coliques-bebe",
    "https://www.nestlebaby.be/fr/aliments-solides-bebe-nouvelles-etapes",
    "https://www.nestlebaby.be/fr/soulager-bebe-mal-de-dent",
    "https://www.nestlebaby.be/fr/apprentissage-biberon-allaitement",
    "https://www.nestlebaby.be/fr/premiere-puree-legumes-bebe",
    "https://www.nestlebaby.be/fr/alimentation-equilibree-jeunes-enfants",
    "https://www.nestlebaby.be/fr/kit-de-diversification-alimentaire-bebe",
    "https://www.nestlebaby.be/fr/preparation-biberon-bebe",
    "https://www.nestlebaby.be/fr/quel-biberon-choisir",
    "https://www.nestlebaby.be/fr/preparer-allaitement",
    "https://www.nestlebaby.be/fr/cereales-energie-bebe",
    "https://www.nestlebaby.be/fr/conseils-pour-donner-le-biberon",
    "https://www.nestlebaby.be/fr/comprendre-pleurs-bebe",
    "https://www.nestlebaby.be/fr/developpement-cerebral-bebe",
    "https://www.nestlebaby.be/fr/sevrage-arreter-allaitement",
    "https://www.nestlebaby.be/fr/laver-bebe",
    "https://www.nestlebaby.be/fr/etapes-developpement-bebe",
    "https://www.nestlebaby.be/fr/bienfaits-allaitement-bebe",
    "https://www.nestlebaby.be/fr/bien-dormir-bebe",
    "https://www.nestlebaby.be/fr/a-qui-confier-bebe",
    "https://www.nestlebaby.be/fr/bobo-ventre-bebe",
    "https://www.nestlebaby.be/fr/allaitement-travail",
    "https://www.nestlebaby.be/fr/manger-allaitement",
    "https://www.nestlebaby.be/fr/allaitement-mixte-alterner-biberon",
    "https://www.nestlebaby.be/fr/masser-bebe",
    "https://www.nestlebaby.be/fr/premiere-dent-bebe",
    "https://www.nestlebaby.be/fr/proteines-lait-maternel-allergies",
    "https://www.nestlebaby.be/fr/lait-maternel-nutrition",
    "https://www.nestlebaby.be/fr/prevenir-obesite-enfants",
    "https://www.nestlebaby.be/fr/diarrhee-bebe",
    "https://www.nestlebaby.be/fr/commencer-donner-nourriture-bebe",
    "https://www.nestlebaby.be/fr/conseils-habitudes-sommeil-de-bebe",
    "https://www.nestlebaby.be/fr/importance-proteines-lait-maternel",
    "https://www.nestlebaby.be/fr/sommeil-bebe-6-12-mois",
    "https://www.nestlebaby.be/fr/plan-d-action-contre-les-coliques",
    "https://www.nestlebaby.be/fr/positions-allaitement",
    "https://www.nestlebaby.be/fr/questions-visite-obligatoire-de-bebe",
    "https://www.nestlebaby.be/fr/troubles-du-sommeil-de-bebe",
    "https://www.nestlebaby.be/fr/cauchemars-bebe",
    "https://www.nestlebaby.be/fr/conseils-pour-allaitement",
    "https://www.nestlebaby.be/fr/vaccination-du-bebe",
    "https://www.nestlebaby.be/fr/constipation-bebe",
    "https://www.nestlebaby.be/fr/comment-donner-le-bain-a-bebe",
    "https://www.nestlebaby.be/fr/pourquoi-les-bebes-pleurent",
    "https://www.nestlebaby.be/fr/calcium-os-bebe",
    "https://www.nestlebaby.be/fr/allaitement-quantite-lait",
    "https://www.nestlebaby.be/fr/avantages-allaitement-maman",
    "https://www.nestlebaby.be/fr/bebe-pleure"
]


# === Fichier CSV de sortie ===
csv_filename = "grossesse_postnatales.csv"

# Création du fichier CSV
with open(csv_filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["id", "question", "reponse", "categorie"])

    id_counter = 1

    for url in urls:
        print(f"Scraping : {url}")
        try:
            response = requests.get(url, timeout=15)
            if response.status_code != 200:
                print(f" Erreur {response.status_code} pour {url}")
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extraction des titres h1 et h2 (considérés comme "questions")
            titles = [h.get_text(strip=True) for h in soup.find_all(["h1", "h2"])]

            # Extraction du texte des paragraphes
            paragraphs = [p.get_text(strip=True) for p in soup.find_all("p")]

            # On fusionne le contenu pour obtenir une "réponse" cohérente
            reponse = " ".join(paragraphs)

            # Catégorie = 'grossesse' (à modifier selon besoin)
            categorie = "grossesse postnatale"

            # Enregistrement dans le CSV
            for title in titles:
                writer.writerow([id_counter, title, reponse, categorie])
                id_counter += 1

            print(f" {url} traité ({len(titles)} questions)")

        except Exception as e:
            print(f" Erreur sur {url} : {e}")

        time.sleep(1)  # petite pause pour éviter surcharge du site

print(f"\n Extraction terminée ! Données enregistrées dans {csv_filename}")
# Out:
# Scraping : https://www.nestlebaby.be/fr/quel-lait-infantile-choisir
#  https://www.nestlebaby.be/fr/quel-lait-infantile-choisir traité (10 questions)
# Scraping : https://www.nestlebaby.be/fr/quantite-biberon-bebe
#  https://www.nestlebaby.be/fr/quantite-biberon-bebe traité (6 questions)
# Scraping : https://www.nestlebaby.be/fr/decrypter-couleur-selles-bebe
#  https://www.nestlebaby.be/fr/decrypter-couleur-selles-bebe traité (6 questions)
# Scraping : https://www.nestlebaby.be/fr/soulager-coliques-bebe
#  https://www.nestlebaby.be/fr/soulager-coliques-bebe traité (5 questions)
# Scraping : https://www.nestlebaby.be/fr/aliments-solides-bebe-nouvelles-etapes
#  https://www.nestlebaby.be/fr/aliments-solides-bebe-nouvelles-etapes traité (1 questions)
# Scraping : https://www.nestlebaby.be/fr/soulager-bebe-mal-de-dent
#  https://www.nestlebaby.be/fr/soulager-bebe-mal-de-dent traité (8 questions)
# Scraping : https://www.nestlebaby.be/fr/apprentissage-biberon-allaitement
# ...
